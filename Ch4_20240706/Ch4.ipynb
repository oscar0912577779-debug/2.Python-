# %% [markdown]
# ## The .apply() method

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df["CC Number"][0]
# Out:
# 3560325168603410

# %%
def last_four(num):
    return str(num)[-4:]

# %%
last_four(df["CC Number"][0])
# Out:
# '3410'

# %%
df['last_four']=df["CC Number"].apply(last_four)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %%
def yelp(price):
    if price<10:
        return "$"
    elif price >=10 and price <30:
        return "$$"
    else:
        return "$$$"
df["Expensive"]=df["total_bill"].apply(yelp)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$

# %%
df["total_bill"].apply(lambda bill:bill*0.18)
# Out:
# 0      3.0582
# 1      1.8612
# 2      3.7818
# 3      4.2624
# 4      4.4262
#         ...
# 239    5.2254
# 240    4.8924
# 241    4.0806
# 242    3.2076
# 243    3.3804
# Name: total_bill, Length: 244, dtype: float64

# %%
def quality(toatal_bill,tip):
    if tip/toatal_bill>0.25:
        return "Generous"
    else:
        return "other"
df["Tip Quality"] = df[["total_bill","tip"]].apply(lambda df:quality(df["total_bill"],df["tip"]),axis=1)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality
# 0       other
# 1       other
# 2       other
# 3       other
# 4       other

# %% [markdown]
# ## sort_values

# %%
df.sort_values("tip")
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 67        Tiffany Brock  4359488526995267    Sat3455      5267         $
# 236       Matthew Myers  3543676378973965    Sat5032      3965        $$
# 92         Leah Ramirez  3508911676966392    Fri3780      6392         $
# 111         Terri Jones  3559221007826887    Sat4801      6887         $
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        $$
# ..                  ...               ...        ...       ...       ...
# 141      Steven Carlson  3526515703718508   Thur1025      8508       $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595       $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808       $$$
# 212     Alex Williamson      676218815212    Sat4590      5212       $$$
# 170       Gregory Clark  5473850968388236    Sat1954      8236       $$$
#
#     Tip Quality
# 67     Generous
# 236       other
# 92        other
# 111       other
# 0         other
# ..          ...
# 141       other
# 59        other
# 23        other
# 212       other
# 170       other
#
# [244 rows x 14 columns]

# %%
df.sort_values(['tip','size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 67        Tiffany Brock  4359488526995267    Sat3455      5267         $
# 111         Terri Jones  3559221007826887    Sat4801      6887         $
# 92         Leah Ramirez  3508911676966392    Fri3780      6392         $
# 236       Matthew Myers  3543676378973965    Sat5032      3965        $$
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        $$
# ..                  ...               ...        ...       ...       ...
# 141      Steven Carlson  3526515703718508   Thur1025      8508       $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595       $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808       $$$
# 212     Alex Williamson      676218815212    Sat4590      5212       $$$
# 170       Gregory Clark  5473850968388236    Sat1954      8236       $$$
#
#     Tip Quality
# 67     Generous
# 111       other
# 92        other
# 236       other
# 0         other
# ..          ...
# 141       other
# 59        other
# 23        other
# 212       other
# 170       other
#
# [244 rows x 14 columns]

# %%
df.sort_values(['tip','size'],ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 170       Gregory Clark  5473850968388236    Sat1954      8236       $$$
# 212     Alex Williamson      676218815212    Sat4590      5212       $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808       $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595       $$$
# 141      Steven Carlson  3526515703718508   Thur1025      8508       $$$
# ..                  ...               ...        ...       ...       ...
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 92         Leah Ramirez  3508911676966392    Fri3780      6392         $
# 236       Matthew Myers  3543676378973965    Sat5032      3965        $$
# 67        Tiffany Brock  4359488526995267    Sat3455      5267         $
# 111         Terri Jones  3559221007826887    Sat4801      6887         $
#
#     Tip Quality
# 170       other
# 212       other
# 23        other
# 59        other
# 141       other
# ..          ...
# 0         other
# 92        other
# 236       other
# 67     Generous
# 111       other
#
# [244 rows x 14 columns]

# %%
df[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
print(df["total_bill"].max())
print(df["total_bill"].idxmax())
print(df.iloc[170])
# Out:
# 50.81
# 170
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# last_four                       8236
# Expensive                        $$$
# Tip Quality                    other
# Name: 170, dtype: object

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df["time"].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %% [markdown]
# ### map

# %%
my_map={"Dinner":"D","Lunch":"L"}
df["time"].map(my_map)
# Out:
# 0      D
# 1      D
# 2      D
# 3      D
# 4      D
#       ..
# 239    D
# 240    D
# 241    D
# 242    D
# 243    D
# Name: time, Length: 244, dtype: object

# %%
my_map1={"Dinner":"1","Lunch":"0"}
df["time"].map(my_map1)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 239    1
# 240    1
# 241    1
# 242    1
# 243    1
# Name: time, Length: 244, dtype: object

# %%
import pandas as pd
#有序
# 使用 pd.Categorical 將 day 欄位轉換為數字
df = pd.DataFrame({'day': ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']})
#ordered=True 表示會根據 categories 分配數字
df['day_number'] = pd.Categorical(df['day'], categories=[ 'Sun','Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']).codes
print(df)
# Out:
#    day  day_number
# 0  Sun           0
# 1  Mon           1
# 2  Tue           2
# 3  Wed           3
# 4  Thu           4
# 5  Fri           5
# 6  Sat           6

# %% [markdown]
# ## enumerate

# %%
fruits = ['apple', 'banana', 'cherry']
for index, fruit in enumerate(fruits):
    print(index, fruit)
# Out:
# 0 apple
# 1 banana
# 2 cherry

# %%
import pandas as pd
# 範例資料
data = {
    'day': ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
}
df = pd.DataFrame(data)
# 定義自訂的順序
custom_order = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
# 使用 enumerate 將文字欄位轉換為數字
def convert_to_numeric_custom_order(df, col, order):
    mapping = {category: i for i, category in enumerate(order)}
    df[col + '_number'] = df[col].map(mapping)
    return df
# 將 'day' 欄位按照自訂順序轉換為數字
df = convert_to_numeric_custom_order(df, 'day', custom_order)
# 顯示轉換後的 DataFrame
print(df)
# Out:
#    day  day_number
# 0  Sun           6
# 1  Mon           0
# 2  Tue           1
# 3  Wed           2
# 4  Thu           3
# 5  Fri           4
# 6  Sat           5
# 7  Sun           6

# %% [markdown]
# ## Combining DataFrames

# %%
data_one = {'A': ['A0', 'A1', 'A2', 'A3'],'B': ['B0', 'B1', 'B2', 'B3']}
data_two = {'C': ['C0', 'C1', 'C2', 'C3'], 'D': ['D0', 'D1', 'D2', 'D3']}
one = pd.DataFrame(data_one)
two = pd.DataFrame(data_two)

# %%
one
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
two
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
axis0=pd.concat([one,two],axis=0)
axis0
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
axis0=pd.concat([one,two],axis=0,ignore_index=True)
axis0
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 4  NaN  NaN   C0   D0
# 5  NaN  NaN   C1   D1
# 6  NaN  NaN   C2   D2
# 7  NaN  NaN   C3   D3

# %%
axis1=pd.concat([one,two],axis=1)
axis1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %% [markdown]
# ## Merge

# %%
registrations = pd.DataFrame({'reg_id':[1,2,3,4],'name':['Andrew','Bobo','Claire','David']})
logins = pd.DataFrame({'log_id':[1,2,3,4],'name':['Xavier','Andrew','Yolanda','Bobo']})

# %%
registrations
# Out:
#    reg_id    name
# 0       1  Andrew
# 1       2    Bobo
# 2       3  Claire
# 3       4   David

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %% [markdown]
# ## Inner Join
# Inner 表示左右表都擁有的欄位內容

# %%
pd.merge(registrations,logins,how="inner",on="name")
# Out:
#    reg_id    name  log_id
# 0       1  Andrew       2
# 1       2    Bobo       4

# %% [markdown]
# ## Left Join
# left 表示左表全部顯示 右表跟左表有關係的才顯示

# %%
pd.merge(registrations,logins,how="left",on="name")
# Out:
#    reg_id    name  log_id
# 0       1  Andrew     2.0
# 1       2    Bobo     4.0
# 2       3  Claire     NaN
# 3       4   David     NaN

# %% [markdown]
# ## Right Join
# right 表示右表全部顯示 左表跟右表有關係的才顯示

# %%
pd.merge(registrations,logins,how="right",on="name")
# Out:
#    reg_id     name  log_id
# 0     NaN   Xavier       1
# 1     1.0   Andrew       2
# 2     NaN  Yolanda       3
# 3     2.0     Bobo       4

# %% [markdown]
# ## Outer Join
# 左右表全部顯示

# %%
pd.merge(registrations,logins,how="outer",on="name")
# Out:
#    reg_id     name  log_id
# 0     1.0   Andrew     2.0
# 1     2.0     Bobo     4.0
# 2     3.0   Claire     NaN
# 3     4.0    David     NaN
# 4     NaN   Xavier     1.0
# 5     NaN  Yolanda     3.0

# %% [markdown]
# # Pivot Tables(樞紐分析表)

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('Sales_Funnel_CRM.csv')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
licenses = df[["Company","Product","Licenses"]]
pd.pivot(data = licenses,index="Company",columns="Product",values="Licenses" )
# Out:
# Product       Analytics  GPS Positioning  Prediction  Tracking
# Company
#  Google           150.0              NaN       150.0     300.0
# ATT                 NaN              NaN       150.0     150.0
# Apple             300.0              NaN         NaN       NaN
# BOBO              150.0              NaN         NaN       NaN
# CVS Health          NaN              NaN         NaN     450.0
# Cisco             300.0            300.0         NaN       NaN
# Exxon Mobile      150.0              NaN         NaN       NaN
# IKEA              300.0              NaN         NaN       NaN
# Microsoft           NaN              NaN         NaN     300.0
# Salesforce        750.0              NaN         NaN       NaN
# Tesla Inc.        300.0              NaN       150.0       NaN
# Walmart           150.0              NaN         NaN       NaN

# %%
pd.pivot_table(df,index="Company",aggfunc="sum")
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_4484\1592028504.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df,index="Company",aggfunc="sum")
#               Account Number  Licenses  Sale Price
# Company
#  Google              6370194       600     3150000
# ATT                  1396064       300     1050000
# Apple                 405886       300     4550000
# BOBO                 2192650       150     2450000
# CVS Health            902797       450      490000
# Cisco                4338998       600     4900000
# Exxon Mobile          470248       150     2100000
# IKEA                  420496       300     4550000
# Microsoft            1216870       300      350000
# Salesforce           2046943       750     7000000
# Tesla Inc.           1273370       450     3500000
# Walmart              2200450       150     2450000

# %%
pd.pivot_table(df,index="Company",aggfunc="sum")[["Licenses","Sale Price"]]
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_4484\2788907978.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df,index="Company",aggfunc="sum")[["Licenses","Sale Price"]]
#               Licenses  Sale Price
# Company
#  Google            600     3150000
# ATT                300     1050000
# Apple              300     4550000
# BOBO               150     2450000
# CVS Health         450      490000
# Cisco              600     4900000
# Exxon Mobile       150     2100000
# IKEA               300     4550000
# Microsoft          300      350000
# Salesforce         750     7000000
# Tesla Inc.         450     3500000
# Walmart            150     2450000

# %%
df.groupby('Company').sum()[['Licenses','Sale Price']]
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_4484\1690882569.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Company').sum()[['Licenses','Sale Price']]
#               Licenses  Sale Price
# Company
#  Google            600     3150000
# ATT                300     1050000
# Apple              300     4550000
# BOBO               150     2450000
# CVS Health         450      490000
# Cisco              600     4900000
# Exxon Mobile       150     2100000
# IKEA               300     4550000
# Microsoft          300      350000
# Salesforce         750     7000000
# Tesla Inc.         450     3500000
# Walmart            150     2450000

# %%
df.groupby('Company').sum(['Licenses','Sale Price'])
# Out:
#               Account Number  Licenses  Sale Price
# Company
#  Google              6370194       600     3150000
# ATT                  1396064       300     1050000
# Apple                 405886       300     4550000
# BOBO                 2192650       150     2450000
# CVS Health            902797       450      490000
# Cisco                4338998       600     4900000
# Exxon Mobile          470248       150     2100000
# IKEA                  420496       300     4550000
# Microsoft            1216870       300      350000
# Salesforce           2046943       750     7000000
# Tesla Inc.           1273370       450     3500000
# Walmart              2200450       150     2450000

# %%
pd.pivot_table(df,index=["Account Manager","Contact"],values=['Sale Price'],aggfunc='sum')
# Out:
#                               Sale Price
# Account Manager Contact
# Claude Shannon  Cindy Phoner     7700000
#                 Emma Gordian    12390000
# Edward Thorp    Elon Tusk        8050000
#                 Larry Pager      5600000
#                 Will Grates      2800000

# %%
pd.pivot_table(df,index=["Account Manager","Contact"],values=["Sale Price"],columns=["Product"],aggfunc=["sum"],fill_value=0)
# Out:
#                                     sum
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner    6650000               0     700000   350000
#                 Emma Gordian   11550000          350000          0   490000
# Edward Thorp    Elon Tusk       7350000               0     700000        0
#                 Larry Pager     4550000               0     700000   350000
#                 Will Grates     2450000               0          0   350000

# %% [markdown]
# # seaborn

# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv("dm_office_sales.csv")
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %% [markdown]
# # Scatterplot

# %%
sns.scatterplot(x="salary",y="sales",data=df)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.scatterplot(x="salary",y="sales",data=df)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.scatterplot(x="salary",y="sales",data=df,hue="division")
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.scatterplot(x="salary",y="sales",data=df,hue="work experience")
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.scatterplot(x="salary",y="sales",data=df,hue="work experience",palette="YlOrBr")
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="salary",y="sales",data=df,hue="work experience",palette="YlOrBr",s=100)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="salary",y="sales",data=df,hue="work experience",palette="YlOrBr",s=100,alpha=0.5)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.scatterplot(x="salary",y="sales",data=df,hue="work experience",style="level of education",s=80)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="salary",y="sales",data=df,hue="work experience",style="level of education",s=80)
plt.savefig("my.jpg")

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   division            1000 non-null   object
#  1   level of education  1000 non-null   object
#  2   training level      1000 non-null   int64
#  3   work experience     1000 non-null   int64
#  4   salary              1000 non-null   int64
#  5   sales               1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %% [markdown]
# ## 分布

# %%
import seaborn as sns
sns.rugplot(x='salary',data=df)
# Out:
# <Axes: xlabel='salary'>

# %%
sns.displot(data=df,x='salary',kde=True) #kde 平滑數據分佈曲線

# %% [markdown]
# # 類別圖表

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='division',data=df)
# Out:
# <Axes: xlabel='division', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='division',data=df,hue='division')
# Out:
# <Axes: xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='level of education',data=df,hue='training level')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='level of education',data=df,hue='training level',palette='Set1')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("dm_office_sales.csv")
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
plt.figure(figsize=(10,6),dpi=200)
sns.barplot(x='level of education',y='salary',data=df,estimator=np.mean,ci='sd')
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_4484\2726766665.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='level of education',y='salary',data=df,estimator=np.mean,ci='sd')
# <Axes: xlabel='level of education', ylabel='salary'>

# %%
plt.figure(figsize=(10,6),dpi=200)
sns.barplot(x='level of education',y='salary',data=df,estimator=np.mean,errorbar='sd')
# Out:
# <Axes: xlabel='level of education', ylabel='salary'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='parental level of education',y='math score',data=df,hue="parental level of education")
# Out:
# <Axes: xlabel='parental level of education', ylabel='math score'>

# %%
sns.jointplot(x='math score',y='reading score',data=df)

# %% [markdown]
# ## pairplot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='gender',palette='viridis')

# %%
sns.pairplot(df,hue='gender',palette='viridis',corner=True)

# %%
sns.pairplot(df,hue='gender',palette='viridis',diag_kind='hist')

# %% [markdown]
# # Matrix Plots

# %%
df=pd.read_csv('country_table.csv')
df
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
# 5           78.880                 16.939        12.79
# 6           72.766                 27.492        10.36

# %%
df=df.set_index('Countries')
df
sns.heatmap(df)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.heatmap(df,linewidths=0.5)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.heatmap(df,linewidths=0.5,annot=True)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.heatmap(df,linewidths=0.5,annot=True,cmap='plasma')
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.clustermap(df,linewidths=0.5,annot=True)

# %%
sns.clustermap(df,col_cluster=False)
